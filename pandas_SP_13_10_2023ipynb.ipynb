# %% [markdown]
# <a href="https://colab.research.google.com/github/KavilaViswanathan/TodoList/blob/main/pandas_SP_13_10_2023ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numpy(position indexing)
#
# Pandas(position indexing,Row and Column)
#
# Polars -> big data
#
# Data process -> pandas
#
# **Roboflow provide a full computer vision pipeline-> data , organise , label , process, train , model , deploy**
#
# Pandas ->  is a software library for data manipulation and data analysis
#
# 1.   series->1D
# 2.   dataframe->2D
#
# **Numpy** -> access only by index
#
# **pandas** -> access by both tha rows and columns
#
# T4 GPU->Tensor process
#
# CPU -> less cores
#
# GPU -> more cores

# %%
import pandas as pd
import numpy as np

# %%
a = np.array([10,12,13,44,56])
a
# Out:
# array([10, 12, 13, 44, 56])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[1]
# Out:
# 12

# %%
b = pd.Series([10,12,13,44,56]) # series-> one dimensional data
b
# Out:
# 0    10
# 1    12
# 2    13
# 3    44
# 4    56
# dtype: int64

# %%
b.drop(1)
# Out:
# 0    10
# 2    13
# 3    44
# 4    56
# dtype: int64

# %%
b[1]
# Out:
# 12

# %%
b.drop(1,inplace = True)
b
# Out:
# 0    10
# 2    13
# 3    44
# 4    56
# dtype: int64

# %%
b[1]
# Out:
# 12

# %%
print(b.iloc[1]) # value retrieve based on the given index 0, 1, 2, 3
print(b.index)
print(b.loc[3]) # value retrieve only based on the given index 0, 2, 3, 4
# error->b.loc[1]
# Out:
# 12
# RangeIndex(start=0, stop=5, step=1)
# 44

# %%
b = pd.Series([10,12,13,44,56],index = ['a','a','c','d','e'])
# error -> b[a]
b.loc['a']
# Out:
# a    10
# a    12
# dtype: int64

# %%
b.iloc[1]
# Out:
# 12

# %%
data = [
    ["Alex",10,"23=05-2000"],
    ["Bob",None,None],
    ["Clarke",None,"23=05-2003"],
]
df = pd.DataFrame(data)
df
# df1 = pd.DataFrame([data])
# 0	1	2
# 0	[Alex, 10, 23=05-2000]	[Bob, None, None]	[Clarke, None, 23=05-2003]
# df1
# Out:
#         0     1           2
# 0    Alex  10.0  23=05-2000
# 1     Bob   NaN        None
# 2  Clarke   NaN  23=05-2003

# %%
df[0:1]
# Out:
#       0     1           2
# 0  Alex  10.0  23=05-2000

# %%
df[0:3]
# Out:
#         0     1           2
# 0    Alex  10.0  23=05-2000
# 1     Bob   NaN        None
# 2  Clarke   NaN  23=05-2003

# %%
df[0][0]
# Out:
# 'Alex'

# %%
df[[0,2]] #->specified column
# Out:
#         0           2
# 0    Alex  23=05-2000
# 1     Bob        None
# 2  Clarke  23=05-2003

# %%
df[0][1]
# Out:
# 'Bob'

# %%
df[1:2]
# Out:
#      0   1     2
# 1  Bob NaN  None

# %%
data = [
    ["Alex",10,"23=05-2000"],
    ["Bob",None,None],
    ["Clarke",None,"23=05-2003"],
]
df = pd.DataFrame(data,columns=["name","age","DOB"])
df['age']
# Out:
# 0    10.0
# 1     NaN
# 2     NaN
# Name: age, dtype: float64

# %%
df['name'][0]
# Out:
# 'Alex'

# %%
df.loc[0,"name"]
# Out:
# 'Alex'

# %%
df[0:1]
# Out:
#    name   age         DOB
# 0  Alex  10.0  23=05-2000

# %%
a = pd.Series([5,10,15,20,25])
a.plot()
# Out:
# <Axes: >

# %%
a.hist(bins=2)
# Out:
# <Axes: >

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a=a.to_numpy()
print(a) #convert it into numpy
print(type(a))
# Out:
# [ 5 10 15 20 25]
# <class 'numpy.ndarray'>

# %%
df.head()
# Out:
#      name   age         DOB
# 0    Alex  10.0  23=05-2000
# 1     Bob   NaN        None
# 2  Clarke   NaN  23=05-2003

# %%
df.head(1)
# Out:
#    name   age         DOB
# 0  Alex  10.0  23=05-2000

# %%
df.tail(1) #last row
# Out:
#      name  age         DOB
# 2  Clarke  NaN  23=05-2003

# %%
df.tail(-2)
# Out:
#      name  age         DOB
# 2  Clarke  NaN  23=05-2003

# %%
#None, ' ','','-','?','Nil',np.nan(not a number)

# %%
df.isnull().sum()
# Out:
# name    0
# age     2
# DOB     1
# dtype: int64

# %%
data = [
    ["Alex",10,"23-05-2000"],
    ["Bob",None,None],
    ["Clarke",None,"23-05-2003"],
    ["John",27,"23-05-205"],
    ["Joo",32,"23-05-2003"],
    ["Clarke",23,"22-5-2003"],
    ["Clarke",43,"1-5-2003"],
    ["Clarke",32,None],
    ["Clarke",21,"6-06-2003"],
    ["Clarke",22,"30-04-2003"],
]
df1 = pd.DataFrame(data,columns=["name","age","DOB"])
df1.isnull().sum()
# Out:
# name    0
# age     2
# DOB     2
# dtype: int64

# %%
df1.dropna()
# Out:
#      name   age         DOB
# 0    Alex  10.0  23-05-2000
# 3    John  27.0   23-05-205
# 4     Joo  32.0  23-05-2003
# 5  Clarke  23.0   22-5-2003
# 6  Clarke  43.0    1-5-2003
# 8  Clarke  21.0   6-06-2003
# 9  Clarke  22.0  30-04-2003

# %%
df1.dropna()
df1
# Out:
#      name   age         DOB
# 0    Alex  10.0  23-05-2000
# 1     Bob   NaN        None
# 2  Clarke   NaN  23-05-2003
# 3    John  27.0   23-05-205
# 4     Joo  32.0  23-05-2003
# 5  Clarke  23.0   22-5-2003
# 6  Clarke  43.0    1-5-2003
# 7  Clarke  32.0        None
# 8  Clarke  21.0   6-06-2003
# 9  Clarke  22.0  30-04-2003

# %%
df1.drop(['age'],axis = 1)
df1
# Out:
#      name   age         DOB
# 0    Alex  10.0  23-05-2000
# 1     Bob   NaN        None
# 2  Clarke   NaN  23-05-2003
# 3    John  27.0   23-05-205
# 4     Joo  32.0  23-05-2003
# 5  Clarke  23.0   22-5-2003
# 6  Clarke  43.0    1-5-2003
# 7  Clarke  32.0        None
# 8  Clarke  21.0   6-06-2003
# 9  Clarke  22.0  30-04-2003

# %%
df.drop([0,2])
# Out:
#   name  age   DOB
# 1  Bob  NaN  None

# %%
df1.drop([0,2],inplace=True) # remove the 0 and 2 row
df1
# Out:
#      name   age         DOB
# 1     Bob   NaN        None
# 3    John  27.0   23-05-205
# 4     Joo  32.0  23-05-2003
# 5  Clarke  23.0   22-5-2003
# 6  Clarke  43.0    1-5-2003
# 7  Clarke  32.0        None
# 8  Clarke  21.0   6-06-2003
# 9  Clarke  22.0  30-04-2003

# %%
a = np.array([10,12,13,44,56])
a
# Out:
# array([10, 12, 13, 44, 56])

# %%
a>40
# Out:
# array([False, False, False,  True,  True])

# %%
a[a>40]
# Out:
# array([44, 56])

# %%
a[a%2!=0]
# Out:
# array([13])

# %%
a[a%2==0]
# Out:
# array([10, 12, 44, 56])

# %%
df
# Out:
#      name   age         DOB
# 0    Alex  10.0  23=05-2000
# 1     Bob   NaN   30-3-2004
# 2  Clarke   NaN  23=05-2003

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     1 non-null      float64
#  2   DOB     2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df['name'].str.contains('e') #display frue or false if its conatins e
# Out:
# 0     True
# 1    False
# 2     True
# Name: name, dtype: bool

# %%
df['name'].str.contains('b')
# Out:
# 0    False
# 1     True
# 2    False
# Name: name, dtype: bool

# %%
print(df['DOB'][0])
# Out:
# 23=05-2000

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (3, 3)
# 9
# [RangeIndex(start=0, stop=3, step=1), Index(['name', 'age', 'DOB'], dtype='object')]
# 2
# name     object
# age     float64
# DOB      object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['name', 'age', 'DOB'], dtype='object')
# [['Alex' 10.0 '23=05-2000']
#  ['Bob' nan None]
#  ['Clarke' nan '23=05-2003']]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     1 non-null      float64
#  2   DOB     2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes
# None

# %%
print(df1.head())
print(df1.tail())
# Out:
#      name   age         DOB
# 1     Bob   NaN        None
# 3    John  27.0   23-05-205
# 4     Joo  32.0  23-05-2003
# 5  Clarke  23.0   22-5-2003
# 6  Clarke  43.0    1-5-2003
#      name   age         DOB
# 5  Clarke  23.0   22-5-2003
# 6  Clarke  43.0    1-5-2003
# 7  Clarke  32.0        None
# 8  Clarke  21.0   6-06-2003
# 9  Clarke  22.0  30-04-2003

# %%
f = pd.concat([df,df])

# %%
f = df.describe(include='all')
f
# Out:
#         name   age         DOB
# count      3   1.0           2
# unique     3   NaN           2
# top     Alex   NaN  23=05-2000
# freq       1   NaN           1
# mean     NaN  10.0         NaN
# std      NaN   NaN         NaN
# min      NaN  10.0         NaN
# 25%      NaN  10.0         NaN
# 50%      NaN  10.0         NaN
# 75%      NaN  10.0         NaN
# max      NaN  10.0         NaN

# %%
df.columns
# Out:
# Index(['name', 'age', 'DOB'], dtype='object')

# %%
df['name']
# Out:
# 0      Alex
# 1       Bob
# 2    Clarke
# Name: name, dtype: object

# %%
df.name
# Out:
# 0      Alex
# 1       Bob
# 2    Clarke
# Name: name, dtype: object

# %%
df.DOB[0]
# Out:
# '23=05-2000'

# %%
# df['name','age'] ->error
df[['name','age']]
# Out:
#      name   age
# 0    Alex  10.0
# 1     Bob   NaN
# 2  Clarke   NaN

# %%
df.loc[0][0]
# Out:
# 'Alex'

# %%
df.loc[0,'name']
# Out:
# 'Alex'

# %%
df.iloc[0,1]
# Out:
# 10.0

# %%
df["DOB"][1] = '30-3-2004'
df
# Out:
# <ipython-input-277-0b70b6e7d1a0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DOB"][1] = '30-3-2004'
#      name   age         DOB
# 0    Alex  10.0  23=05-2000
# 1     Bob   NaN   30-3-2004
# 2  Clarke   NaN  23=05-2003

# %%
d = pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")
d
# Out:
# [    Rank  Peak                                          Title  \
#  0      1     1                                         Avatar
#  1      2     1                              Avengers: Endgame
#  2      3     3                       Avatar: The Way of Water
#  3      4     1                                        Titanic
#  4      5     3                   Star Wars: The Force Awakens
#  5      6     4                         Avengers: Infinity War
#  6      7     6                        Spider-Man: No Way Home
#  7      8     3                                 Jurassic World
#  8      9     7                                  The Lion King
#  9     10     3                                   The Avengers
#  10    11     4                                      Furious 7
#  11    12    11                              Top Gun: Maverick
#  12    13    10                                      Frozen II
#  13    14    14                                       Barbie †
# ...

# %%
e = pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
e
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
e.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
type(e.item_price[0])
# Out:
# str

# %%
e.item_price = e.item_price.str.replace("$","")
e.head(10)
# Out:
# <ipython-input-23-e438a7bfb683>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   e.item_price = e.item_price.str.replace("$","")
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
e.item_price = e.item_price.astype(float)
e.item_price
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
type(e.item_price[0])
# Out:
# numpy.float64

# %%
e.item_price * 100
# Out:
# 0        239.0
# 1        339.0
# 2        339.0
# 3        239.0
# 4       1698.0
#          ...
# 4617    1175.0
# 4618    1175.0
# 4619    1125.0
# 4620     875.0
# 4621     875.0
# Name: item_price, Length: 4622, dtype: float64

# %%
e.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
e_drink = e[e.item_price<1.1]
e_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
print(e_drink.item_name.unique())
print()
print(e_drink.item_name.nunique())
# Out:
# ['Canned Soda' 'Bottled Water']
#
# 2

# %%
e_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
e[e.item_name=="Chicken Bowl"]
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
e[e.item_name=="Steak Burrito"].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
e[e.item_name=="Steak Burrito"].choice_description.nunique()
# Out:
# 251

# %%
e.dropna(inplace=True)

# %%
e.choice_description.unique()
# Out:
# array(['[Clementine]', '[Apple]',
#        '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#        ...,
#        '[Roasted Chili Corn Salsa, [Pinto Beans, Sour Cream, Cheese, Lettuce, Guacamole]]',
#        '[Tomatillo Green Chili Salsa, [Rice, Black Beans]]',
#        '[Tomatillo Green Chili Salsa, [Rice, Fajita Vegetables, Black Beans, Guacamole]]'],
#       dtype=object)

# %%
e[e.choice_description.str.contains('Black Beans')].item_name
# Out:
# 4               Chicken Bowl
# 7              Steak Burrito
# 9              Steak Burrito
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
#                 ...
# 4604            Chicken Bowl
# 4608          Veggie Burrito
# 4611          Veggie Burrito
# 4612           Carnitas Bowl
# 4617           Steak Burrito
# Name: item_name, Length: 1345, dtype: object

# %%
e[e.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
e[(e.item_price>10) & (e.item_name=="Chicken Bowl")]
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# 123         54         1  Chicken Bowl
# ...        ...       ...           ...
# 4576      1820         1  Chicken Bowl
# 4586      1824         1  Chicken Bowl
# 4587      1824         1  Chicken Bowl
# 4589      1825         1  Chicken Bowl
# 4590      1825         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# 123   [Fresh Tomato Salsa, [Guacamole, Cheese, Sour ...       11.25
# ...                                                 ...         ...
# ...

# %%
e[(e.item_price<10) & (e.item_name=="Chicken Bowl")].sort_values(["item_price"])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
movies = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.star_rating>=8) & (movies.genre=="Action")]
# Out:
#      star_rating                                           title  \
# 3            9.0                                 The Dark Knight
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 36           8.6                             Saving Private Ryan
# 37           8.6                         Raiders of the Lost Ark
# 43           8.5                           The Dark Knight Rises
# 44           8.5                                       Gladiator
# 45           8.5                      Terminator 2: Judgment Day
# 75           8.4                                          Aliens
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 82           8.4                                      Braveheart
# ...

# %%
movies[(movies.star_rating>=8) & (movies.genre=="Action")].sort_values(["duration"])
# Out:
#      star_rating                                           title  \
# 276          8.1                            A Fistful of Dollars
# 327          8.0                    The Adventures of Robin Hood
# 235          8.1                                         Yip Man
# 281          8.1                                  The Terminator
# 123          8.3                                     The General
# 96           8.4                                         Yojimbo
# 198          8.1                               Kill Bill: Vol. 1
# 349          8.0                                      District 9
# 391          8.0                                Edge of Tomorrow
# 239          8.1                   Elite Squad: The Enemy Within
# 37           8.6                         Raiders of the Lost Ark
# 261          8.1                                     Elite Squad
# 240          8.1                            The Bourne Ultimatum
# ...

# %%
movies.actors_list.unique
# Out:
# <bound method Series.unique of 0      [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1        [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2      [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3      [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4      [u'John Travolta', u'Uma Thurman', u'Samuel L....
#                              ...
# 974    [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975    [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976    [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977    [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978    [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# Name: actors_list, Length: 979, dtype: object>

# %%
movies.actors_list=="Matt Damon"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: actors_list, Length: 979, dtype: bool

# %%
movies[movies.actors_list.str.contains('Matt Damon')]
# Out:
#      star_rating                 title content_rating      genre  duration  \
# 36           8.6   Saving Private Ryan              R     Action       169
# 49           8.5          The Departed              R      Crime       151
# 139          8.3     Good Will Hunting              R      Drama       126
# 240          8.1  The Bourne Ultimatum          PG-13     Action       115
# 411          7.9   The Bourne Identity          PG-13     Action       119
# 567          7.8  The Bourne Supremacy          PG-13     Action       108
# 625          7.7                 Ponyo              G  Animation       101
# 662          7.7             True Grit          PG-13  Adventure       110
#
#                                            actors_list
# 36      [u'Tom Hanks', u'Matt Damon', u'Tom Sizemore']
# 49   [u'Leonardo DiCaprio', u'Matt Damon', u'Jack N...
# 139  [u'Robin Williams', u'Matt Damon', u'Ben Affle...
# 240  [u'Matt Damon', u'\xc9dgar Ram\xedrez', u'Joan...
# ...

# %%
movies[movies.actors_list.str.contains('Matt Damon')].sort_values
# Out:
# <bound method DataFrame.sort_values of      star_rating                 title content_rating      genre  duration  \
# 36           8.6   Saving Private Ryan              R     Action       169
# 49           8.5          The Departed              R      Crime       151
# 139          8.3     Good Will Hunting              R      Drama       126
# 240          8.1  The Bourne Ultimatum          PG-13     Action       115
# 411          7.9   The Bourne Identity          PG-13     Action       119
# 567          7.8  The Bourne Supremacy          PG-13     Action       108
# 625          7.7                 Ponyo              G  Animation       101
# 662          7.7             True Grit          PG-13  Adventure       110
#
#                                            actors_list
# 36      [u'Tom Hanks', u'Matt Damon', u'Tom Sizemore']
# 49   [u'Leonardo DiCaprio', u'Matt Damon', u'Jack N...
# 139  [u'Robin Williams', u'Matt Damon', u'Ben Affle...
# ...

# %%
movies[movies.actors_list.str.contains('Leonardo DiCaprio')].sort_values(['star_rating','duration'],ascending = (False,True))
# Out:
#      star_rating                        title content_rating      genre  \
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 143          8.2      The Wolf of Wall Street              R  Biography
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 620          7.7                      Titanic          PG-13      Drama
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
#
#      duration                                        actors_list
# ...

# %%
ufo = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo["Shape Reported"].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo["Shape Reported"].isnull().sum()
# Out:
# 2644

# %%
drinks = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks['beer_servings'].mean()
# Out:
# 106.16062176165804

# %%
print(drinks['beer_servings'].min())
print(drinks['beer_servings'].max())
# Out:
# 0
# 376

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks[drinks.continent=="Asia"].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent == "Asia"].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
